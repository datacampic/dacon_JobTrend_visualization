# %%
import requests
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
naver = requests.get("https://api.github.com/orgs/naver/repos").json()
naver
# Out:
# [{'id': 4709330,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0NzA5MzMw',
#   'name': 'ngrinder',
#   'full_name': 'naver/ngrinder',
#   'private': False,
#   'owner': {'login': 'naver',
#    'id': 6589568,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY1ODk1Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6589568?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/naver',
#    'html_url': 'https://github.com/naver',
#    'followers_url': 'https://api.github.com/users/naver/followers',
#    'following_url': 'https://api.github.com/users/naver/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/naver/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/naver/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/naver/subscriptions',
#    'organizations_url': 'https://api.github.com/users/naver/orgs',
#    'repos_url': 'https://api.github.com/users/naver/repos',
# ...

# %%
language = {}
headers = {
    "Authorization": "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"
}

for element in naver:
    naver_language = requests.get(element["languages_url"], headers=headers).json()
    for k, v in naver_language.items():
        if k in language.keys():
            language[k] += v
        else:
            language[k] = v

# %%
language
# Out:
# {'Java': 14075669,
#  'Vue': 441312,
#  'JavaScript': 25557257,
#  'FreeMarker': 9845,
#  'Groovy': 28251,
#  'Python': 335938,
#  'CSS': 1279236,
#  'HTML': 188092965,
#  'Shell': 189829,
#  'Dockerfile': 2911,
#  'Batchfile': 8077,
#  'Scala': 25333,
#  'PLSQL': 11068,
#  'PLpgSQL': 545,
#  'SQLPL': 131,
#  'C': 3769684,
#  'Perl': 816441,
#  'M4': 308530,
#  'Makefile': 34294,
#  'DTrace': 11527,
#  'Starlark': 1640,
#  'C++': 3023763,
#  'XS': 66352,
#  'Raku': 40860,
#  'Mako': 13678,
#  'CMake': 6863,
#  'XSLT': 6024,
#  'Ruby': 67964,
#  'Lua': 2729,
#  'GDB': 37,
#  'ActionScript': 14083,
#  'PHP': 3690,
#  'Groff': 160}

# %%
kakao_language = {}
kakao = requests.get("https://api.github.com/orgs/kakao/repos").json()

# %%
for element in kakao:
    lang = requests.get(element["languages_url"]).json()
    for k, v in lang.items():
        if k in kakao_language.keys():
            kakao_language[k] += v
        else:
            kakao_language[k] = v
            
kakao_language
# Out:
# {'JavaScript': 5891851,
#  'HTML': 1273540,
#  'CSS': 187547,
#  'Java': 1157944,
#  'Shell': 118022,
#  'Go': 4898819,
#  'Ruby': 759885,
#  'Scala': 1360707,
#  'Python': 429845,
#  'Clojure': 143062,
#  'Makefile': 10681,
#  'Batchfile': 5006,
#  'Dockerfile': 1337,
#  'Jupyter Notebook': 154017,
#  'C++': 126044,
#  'SWIG': 2428,
#  'C': 12604,
#  'Assembly': 252,
#  'PowerShell': 82}

# %%
coupang_language = {}
coupang = requests.get("https://api.github.com/orgs/coupang/repos").json()

for element in coupang:
    lang = requests.get(element["languages_url"]).json()
    for k, v in lang.items():
        if k in coupang_language.keys():
            coupang_language[k] += v
        else:
            coupang_language[k] = v
            
coupang_language
# Out:
# {'Java': 24570736,
#  'Shell': 183141,
#  'Makefile': 24346,
#  'Batchfile': 59016,
#  'JavaScript': 3494889177,
#  'CSS': 218749507,
#  'CoffeeScript': 10909,
#  'Emacs Lisp': 170,
#  'HTML': 2942976,
#  'Thrift': 6383,
#  'Python': 2036148,
#  'Groovy': 412660,
#  'Ruby': 2610,
#  'Groff': 17806,
#  'Kotlin': 631368,
#  'Go': 2362374,
#  'Scala': 5971859,
#  'XSLT': 7116}

# %%
woowabros_language = {}
woowabros = requests.get("https://api.github.com/orgs/woowabros/repos").json()

for element in woowabros:
    lang = requests.get(element["languages_url"]).json()
    for k, v in lang.items():
        if k in woowabros_language.keys():
            woowabros_language[k] += v
        else:
            woowabros_language[k] = v
            
woowabros_language
# Out:
# {'JavaScript': 1674324,
#  'Java': 5964249,
#  'Scala': 346514,
#  'HTML': 434573,
#  'Shell': 90499,
#  'Python': 989567,
#  'CSS': 305299,
#  'Roff': 60995,
#  'R': 21301,
#  'Dockerfile': 12889,
#  'Batchfile': 12352,
#  'Thrift': 4680,
#  'Ruby': 5686,
#  'XSLT': 1326,
#  'C': 3718,
#  'PowerShell': 1917,
#  'Makefile': 1231,
#  'Mako': 494,
#  'Pascal': 20550,
#  'Visual Basic .NET': 19934,
#  'C#': 18232,
#  'Groovy': 5262}

# %%
daangn_language = {}
daangn = requests.get("https://api.github.com/orgs/daangn/repos").json()

for element in daangn:
    lang = requests.get(element["languages_url"]).json()
    for k, v in lang.items():
        if k in daangn_language.keys():
            daangn_language[k] += v
        else:
            daangn_language[k] = v
            
daangn_language
# Out:
# {'JavaScript': 209804,
#  'HTML': 1234121,
#  'CSS': 80004,
#  'Ruby': 68285,
#  'PHP': 1092,
#  'Nginx': 956,
#  'Shell': 91658,
#  'CoffeeScript': 4921,
#  'Java': 64092,
#  'Swift': 173681,
#  'C++': 6478805,
#  'Python': 1068002,
#  'R': 721,
#  'Makefile': 26506,
#  'Perl': 2083,
#  'Objective-C': 1117619,
#  'Kotlin': 44525,
#  'Cuda': 554517,
#  'C': 49664,
#  'M4': 38112,
#  'CMake': 12092,
#  'Dockerfile': 1297,
#  'Jupyter Notebook': 85515,
#  'Objective-C++': 2810317}

# %%
toss_language = {}
toss = requests.get("https://api.github.com/orgs/toss/repos").json()

for element in toss:
    lang = requests.get(element["languages_url"]).json()
    for k, v in lang.items():
        if k in toss_language.keys():
            toss_language[k] += v
        else:
            toss_language[k] = v
            
toss_language
# Out:
# {'Java': 194356,
#  'Kotlin': 272938,
#  'JavaScript': 1194298,
#  'CSS': 18083,
#  'HTML': 2210,
#  'Shell': 179999,
#  'Smarty': 4996,
#  'Dockerfile': 3201,
#  'Python': 122,
#  'TypeScript': 154292,
#  'Dart': 58139,
#  'Objective-C': 137765,
#  'Ruby': 112477,
#  'Swift': 3935284,
#  'C': 120350,
#  'Gherkin': 50270,
#  'Rich Text Format': 1110,
#  'Objective-C++': 151,
#  'NewLisp': 50,
#  'Go': 55680,
#  'Starlark': 5524,
#  'HCL': 262}

# %%
corporate = pd.read_csv("./corporate.csv", encoding='CP949')
corporate.columns
# Out:
# Index(['기업일련번호', '업체국문명', '업체영문명', '기업한줄소개내용', '기업소개상세내용', '설립일자', '구성원수',
#        '누적투자유치금액', '홈페이지url', '소셜미디어url', '기업추천수', '기업추천내용', '산업구분명', '사무실주소',
#        '기술스택명', '발행사명', '보도일자', '뉴스제목명', '기사url'],
#       dtype='object')

# %%
print(list(corporate["산업구분명"].unique()))
# Out:
# [nan, '교육/이러닝||프로그래밍교육||기업교육||직무교육||정보보안교육', '온라인쇼핑', '웹서비스||여행||오프라인', '제조업||기계장비', '마케팅유통판매통합커머스||애견||애견용품', '유통/소비재||화장품/유통', '#화장품', '데이터||스타트업||데이터분석||SaaS||CRM||운영||협업||노코드||대시보드', '제조업/서비스', '플랫폼', '앱/웹서비스||앱/웹개발||리서치', '콘텐츠||상품개발/상품기획/디자인/제조||패션&라이프스타일||문구', '패션||#웹#SNS#플랫폼||패션&라이프스타일||IT/SNS||IT/SNS', '모바일서비스||웹서비스||소프트웨어||데이터||모바일||빅데이터||인공지능||데이터분석||데이터마이닝||서버||||바이오/헬스케어||바이오/질병진단', '전자상거래||온라인쇼핑몰||플랫폼서비스||공유플랫폼', '전산화학', '서비스기획/운영', 'O2O||서비스||도소매/전자상거래||패션&라이프스타일', '웹서비스||게임개발', 'IT/개발||SW||기업솔루션||프로젝트관리', '웹개발||영화CG', '도소매/전자상거래||제조업/로봇||공유주방||기계제조업', '소프트웨어||웹||앱||모바일||SI||IT개발자', '기상산업', '교육서비스업', '제조업', '바비톡', '스타트업||앱/웹서비스||콘텐츠/영상||유튜브||교육/문화컨텐츠||방송/콘텐츠/교육', '게임개발', '제조업||유통||제조||제조업/서비스||가공식품||도매업||가공식품도매||동충하초||동충하초종균연구||개발및재배', '여행', '구매||MRO||오픈몰||산업재', 'IT/개발', '모바일서비스||웹서비스||스타트업||앱||중고거래||어플||리뷰||순위||평점||중고태블릿||중고스마트폰||중고전자제품', '서비스업/포털및인터넷||소프트웨어개발및공급', '배송||택배||운수||이마트배송||CU편의점||오뚜기산업||동원산업', '모바일서비스||웹서비스||플랫폼||O2O||모빌리티||MICE||외국인관광객||VIP', '벤처캐피탈', 'IT|
# ...

# %%
it = corporate[corporate["산업구분명"] == '소프트웨어||클라우드||렌더링||pricing||분산병렬']
it
# Out:
#        기업일련번호  업체국문명         업체영문명                         기업한줄소개내용  \
# 63218    4858  두리반테크  DooribanTech  분산병렬솔루션 개발 전문업체를 지향하고 있는 스타트업기업
#
#                                                 기업소개상세내용        설립일자 구성원수  \
# 63218  안녕하세요?▦▦두리반테크는 그리드컴퓨팅 기반의 분산병렬처리 솔루션인 그리드 미들웨어...  20110207.0  NaN
#
#        누적투자유치금액                       홈페이지url 소셜미디어url  기업추천수 기업추천내용  \
# 63218       NaN  http://www.dooribantech.com/      NaN      0    NaN
#
#                                  산업구분명                              사무실주소  \
# 63218  소프트웨어||클라우드||렌더링||pricing||분산병렬  대한민국 경기도 안양시 동안구 관양동 1744 5층 518호
#
#       기술스택명  발행사명        보도일자                     뉴스제목명  \
# 63218   NaN  매일경제  20150415.0  [SBA 우수상품] 두리반테크 / 렌더부스터
#
#                                                    기사url
# 63218  http://news.mk.co.kr/newsRead.php?no=692809&ye...

# %%
line_language = {}
line = requests.get("https://api.github.com/orgs/line/repos").json()

for element in line:
    lang = requests.get(element["languages_url"]).json()
    for k, v in lang.items():
        if k in line_language.keys():
            line_language[k] += v
        else:
            line_language[k] = v
            
line_language
# Out:
# {'Java': 18889755,
#  'Objective-C': 29498,
#  'Swift': 52912,
#  'JavaScript': 225373,
#  'TypeScript': 440934,
#  'Thrift': 206446,
#  'Scala': 155283,
#  'Kotlin': 186942,
#  'Less': 34099,
#  'Shell': 10633,
#  'HTML': 174538,
#  'CSS': 44673,
#  'Ruby': 192481,
#  'Perl': 274358,
#  'Raku': 4630,
#  'Go': 562286,
#  'PHP': 750229,
#  'Makefile': 4381,
#  'Python': 1030635,
#  'Dockerfile': 2219,
#  'C++': 1024738,
#  'C': 8493,
#  'Objective-C++': 523,
#  'C#': 74288}

# %%
naver = {'Java': 14075669,
 'Vue': 441312,
 'JavaScript': 25557257,
 'FreeMarker': 9845,
 'Groovy': 28251,
 'Python': 335938,
 'CSS': 1279236,
 'HTML': 188092965,
 'Shell': 189829,
 'Dockerfile': 2911,
 'Batchfile': 8077,
 'Scala': 25333,
 'PLSQL': 11068,
 'PLpgSQL': 545,
 'SQLPL': 131,
 'C': 3769684,
 'Perl': 816441,
 'M4': 308530,
 'Makefile': 34294,
 'DTrace': 11527,
 'Starlark': 1640,
 'C++': 3023763,
 'XS': 66352,
 'Raku': 40860,
 'Mako': 13678,
 'CMake': 6863,
 'XSLT': 6024,
 'Ruby': 67964,
 'Lua': 2729,
 'GDB': 37,
 'ActionScript': 14083,
 'PHP': 3690,
 'Groff': 160}

# %%
kakao = {'JavaScript': 5891851,
 'HTML': 1273540,
 'CSS': 187547,
 'Java': 1157944,
 'Shell': 118022,
 'Go': 4898819,
 'Ruby': 759885,
 'Scala': 1360707,
 'Python': 429845,
 'Clojure': 143062,
 'Makefile': 10681,
 'Batchfile': 5006,
 'Dockerfile': 1337,
 'Jupyter Notebook': 154017,
 'C++': 126044,
 'SWIG': 2428,
 'C': 12604,
 'Assembly': 252,
 'PowerShell': 82}

# %%
coupang = {'Java': 24570736,
 'Shell': 183141,
 'Makefile': 24346,
 'Batchfile': 59016,
 'JavaScript': 3494889177,
 'CSS': 218749507,
 'CoffeeScript': 10909,
 'Emacs Lisp': 170,
 'HTML': 2942976,
 'Thrift': 6383,
 'Python': 2036148,
 'Groovy': 412660,
 'Ruby': 2610,
 'Groff': 17806,
 'Kotlin': 631368,
 'Go': 2362374,
 'Scala': 5971859,
 'XSLT': 7116}

# %%
woowa = {'JavaScript': 1674324,
 'Java': 5964249,
 'Scala': 346514,
 'HTML': 434573,
 'Shell': 90499,
 'Python': 989567,
 'CSS': 305299,
 'Roff': 60995,
 'R': 21301,
 'Dockerfile': 12889,
 'Batchfile': 12352,
 'Thrift': 4680,
 'Ruby': 5686,
 'XSLT': 1326,
 'C': 3718,
 'PowerShell': 1917,
 'Makefile': 1231,
 'Mako': 494,
 'Pascal': 20550,
 'Visual Basic .NET': 19934,
 'C#': 18232,
 'Groovy': 5262}

# %%
daangn = {'Java': 194356,
 'Kotlin': 272938,
 'JavaScript': 1194298,
 'CSS': 18083,
 'HTML': 2210,
 'Shell': 179999,
 'Smarty': 4996,
 'Dockerfile': 3201,
 'Python': 122,
 'TypeScript': 154292,
 'Dart': 58139,
 'Objective-C': 137765,
 'Ruby': 112477,
 'Swift': 3935284,
 'C': 120350,
 'Gherkin': 50270,
 'Rich Text Format': 1110,
 'Objective-C++': 151,
 'NewLisp': 50,
 'Go': 55680,
 'Starlark': 5524,
 'HCL': 262}

# %%
toss = {'Java': 194356,
 'Kotlin': 272938,
 'JavaScript': 1194298,
 'CSS': 18083,
 'HTML': 2210,
 'Shell': 179999,
 'Smarty': 4996,
 'Dockerfile': 3201,
 'Python': 122,
 'TypeScript': 154292,
 'Dart': 58139,
 'Objective-C': 137765,
 'Ruby': 112477,
 'Swift': 3935284,
 'C': 120350,
 'Gherkin': 50270,
 'Rich Text Format': 1110,
 'Objective-C++': 151,
 'NewLisp': 50,
 'Go': 55680,
 'Starlark': 5524,
 'HCL': 262}

# %%
kakao_df = pd.DataFrame(kakao, index=['kakao'])
naver_df = pd.DataFrame(naver, index=['naver'])
coupang_df = pd.DataFrame(coupang, index=['coupang'])
woowa_df = pd.DataFrame(woowa, index=['woowa'])
line_df = pd.DataFrame(line_language, index=['line'])
daangn = pd.DataFrame(daangn, index=['daangn'])
toss = pd.DataFrame(toss, index=['toss'])

# %%
kakao_df
# Out:
#        JavaScript     HTML     CSS     Java   Shell       Go    Ruby    Scala  \
# kakao     5891851  1273540  187547  1157944  118022  4898819  759885  1360707
#
#        Python  Clojure  Makefile  Batchfile  Dockerfile  Jupyter Notebook  \
# kakao  429845   143062     10681       5006        1337            154017
#
#           C++  SWIG      C  Assembly  PowerShell
# kakao  126044  2428  12604       252          82

# %%
it_corporation = pd.concat([kakao_df, naver_df, coupang_df, woowa_df, line_df, daangn, toss])
it_corporation
# Out:
#          JavaScript       HTML        CSS      Java   Shell         Go  \
# kakao       5891851    1273540     187547   1157944  118022  4898819.0
# naver      25557257  188092965    1279236  14075669  189829        NaN
# coupang  3494889177    2942976  218749507  24570736  183141  2362374.0
# woowa       1674324     434573     305299   5964249   90499        NaN
# line         225373     174538      44673  18889755   10633   562286.0
# daangn      1194298       2210      18083    194356  179999    55680.0
# toss        1194298       2210      18083    194356  179999    55680.0
#
#            Ruby      Scala   Python   Clojure  ...      Swift  TypeScript  \
# kakao    759885  1360707.0   429845  143062.0  ...        NaN         NaN
# naver     67964    25333.0   335938       NaN  ...        NaN         NaN
# coupang    2610  5971859.0  2036148       NaN  ...        NaN         NaN
# woowa      5686   346514.0   989567       NaN  ...        NaN         NaN
# ...

# %%
it_corporation.fillna(0, inplace=True)

# %%
it_corporation
# Out:
#          JavaScript       HTML        CSS      Java   Shell         Go  \
# kakao       5891851    1273540     187547   1157944  118022  4898819.0
# naver      25557257  188092965    1279236  14075669  189829        0.0
# coupang  3494889177    2942976  218749507  24570736  183141  2362374.0
# woowa       1674324     434573     305299   5964249   90499        0.0
# line         225373     174538      44673  18889755   10633   562286.0
# daangn      1194298       2210      18083    194356  179999    55680.0
# toss        1194298       2210      18083    194356  179999    55680.0
#
#            Ruby      Scala   Python   Clojure  ...      Swift  TypeScript  \
# kakao    759885  1360707.0   429845  143062.0  ...        0.0         0.0
# naver     67964    25333.0   335938       0.0  ...        0.0         0.0
# coupang    2610  5971859.0  2036148       0.0  ...        0.0         0.0
# woowa      5686   346514.0   989567       0.0  ...        0.0         0.0
# ...

# %%
it_corporation.columns
# Out:
# Index(['JavaScript', 'HTML', 'CSS', 'Java', 'Shell', 'Go', 'Ruby', 'Scala',
#        'Python', 'Clojure', 'Makefile', 'Batchfile', 'Dockerfile',
#        'Jupyter Notebook', 'C++', 'SWIG', 'C', 'Assembly', 'PowerShell', 'Vue',
#        'FreeMarker', 'Groovy', 'PLSQL', 'PLpgSQL', 'SQLPL', 'Perl', 'M4',
#        'DTrace', 'Starlark', 'XS', 'Raku', 'Mako', 'CMake', 'XSLT', 'Lua',
#        'GDB', 'ActionScript', 'PHP', 'Groff', 'CoffeeScript', 'Emacs Lisp',
#        'Thrift', 'Kotlin', 'Roff', 'R', 'Pascal', 'Visual Basic .NET', 'C#',
#        'Objective-C', 'Swift', 'TypeScript', 'Less', 'Objective-C++', 'Smarty',
#        'Dart', 'Gherkin', 'Rich Text Format', 'NewLisp', 'HCL'],
#       dtype='object')

# %%
total = {}

for i in ['JavaScript', 'HTML', 'CSS', 'Java', 'Shell', 'Go', 'Ruby', 'Scala',
       'Python', 'Clojure', 'Makefile', 'Batchfile', 'Dockerfile',
       'Jupyter Notebook', 'C++', 'SWIG', 'C', 'Assembly', 'PowerShell', 'Vue',
       'FreeMarker', 'Groovy', 'PLSQL', 'PLpgSQL', 'SQLPL', 'Perl', 'M4',
       'DTrace', 'Starlark', 'XS', 'Raku', 'Mako', 'CMake', 'XSLT', 'Lua',
       'GDB', 'ActionScript', 'PHP', 'Groff', 'CoffeeScript', 'Emacs Lisp',
       'Thrift', 'Kotlin', 'Roff', 'R', 'Pascal', 'Visual Basic .NET', 'C#',
       'Objective-C', 'Swift', 'TypeScript', 'Less', 'Objective-C++', 'Smarty',
       'Dart', 'Gherkin', 'Rich Text Format', 'NewLisp', 'HCL']:
    
    total[i] = 0

for i in ['JavaScript', 'HTML', 'CSS', 'Java', 'Shell', 'Go', 'Ruby', 'Scala',
       'Python', 'Clojure', 'Makefile', 'Batchfile', 'Dockerfile',
       'Jupyter Notebook', 'C++', 'SWIG', 'C', 'Assembly', 'PowerShell', 'Vue',
       'FreeMarker', 'Groovy', 'PLSQL', 'PLpgSQL', 'SQLPL', 'Perl', 'M4',
       'DTrace', 'Starlark', 'XS', 'Raku', 'Mako', 'CMake', 'XSLT', 'Lua',
       'GDB', 'ActionScript', 'PHP', 'Groff', 'CoffeeScript', 'Emacs Lisp',
       'Thrift', 'Kotlin', 'Roff', 'R', 'Pascal', 'Visual Basic .NET', 'C#',
       'Objective-C', 'Swift', 'TypeScript', 'Less', 'Objective-C++', 'Smarty',
       'Dart', 'Gherkin', 'Rich Text Format', 'NewLisp', 'HCL']:
    
    total[i] += sum(it_corporation[i])

# %%
total = pd.DataFrame(total, index = ["합계"])

# %%
it_corporation = pd.concat([it_corporation, total])

# %%
it_corporation
# Out:
#          JavaScript       HTML        CSS      Java   Shell         Go  \
# kakao       5891851    1273540     187547   1157944  118022  4898819.0
# naver      25557257  188092965    1279236  14075669  189829        0.0
# coupang  3494889177    2942976  218749507  24570736  183141  2362374.0
# woowa       1674324     434573     305299   5964249   90499        0.0
# line         225373     174538      44673  18889755   10633   562286.0
# daangn      1194298       2210      18083    194356  179999    55680.0
# toss        1194298       2210      18083    194356  179999    55680.0
# 합계       3530626578  192923012  220602428  65047065  952122  7934839.0
#
#             Ruby      Scala   Python   Clojure  ...      Swift  TypeScript  \
# kakao     759885  1360707.0   429845  143062.0  ...        0.0         0.0
# naver      67964    25333.0   335938       0.0  ...        0.0         0.0
# coupang     2610  5971859.0  2036148       0.0  ...        0.0         0.0
# ...

# %%
it_corporation.to_csv("./it_corporation.csv")
